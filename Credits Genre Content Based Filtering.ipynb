# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("data_4.csv")

# %%
data.columns
# Out:
# Index(['director_name', 'actor_1_name', 'actor_2_name', 'actor_3_name',
#        'genres', 'movie_title', 'comb', 'overview'],
#       dtype='object')

# %%
# Function to convert all strings to lower case and strip names of spaces
def clean_data(x):
    if isinstance(x, list):
        return [str.lower(i.replace(" ", "")) for i in x]
    else:
        #Check if director exists. If not, return empty string
        if isinstance(x, str):
            return str.lower(x.replace(" ", ""))
        else:
            return ''

# %%
# Apply clean_data function to your features.
features = ['actor_1_name', 'actor_2_name', 'actor_3_name', 'director_name']

for feature in features:
    data[feature] = data[feature].apply(clean_data)

# %%
data.head(2)
# Out:
#    director_name actor_1_name    actor_2_name   actor_3_name  \
# 0   jamescameron   cchpounder  joeldavidmoore       wesstudi
# 1  goreverbinski   johnnydepp    orlandobloom  jackdavenport
#
#                             genres                               movie_title  \
# 0  Action Adventure Fantasy Sci-Fi                                    avatar
# 1         Action Adventure Fantasy  pirates of the caribbean: at world's end
#
#                                                 comb  \
# 0  CCH Pounder Joel David Moore Wes Studi James C...
# 1  Johnny Depp Orlando Bloom Jack Davenport Gore ...
#
#                                             overview
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...

# %%
def create_soup(x):
    return x['actor_1_name'] + ' '+ x['actor_2_name'] + ' ' + x['actor_3_name'] + ' ' + x['director_name'] + ' ' + x['genres']

data['soup'] = data.apply(create_soup, axis=1)

# %%
data['soup'][1]
# Out:
# 'johnnydepp orlandobloom jackdavenport goreverbinski Action Adventure Fantasy'

# %%
# Import CountVectorizer and create the count matrix
from sklearn.feature_extraction.text import CountVectorizer

count = CountVectorizer(stop_words='english')
count_matrix = count.fit_transform(data['soup'])

# %%
# Compute the Cosine Similarity matrix based on the count_matrix
from sklearn.metrics.pairwise import cosine_similarity

cosine_sim = cosine_similarity(count_matrix, count_matrix)

# %%
# Reset index of our main DataFrame and construct reverse mapping as before
data = data.reset_index(drop=True)
indices = pd.Series(data.index, index=data['movie_title'])

# %%
indices['avatar']
# Out:
# 0

# %%
# Function that takes in movie title as input and outputs most similar movies
def get_recommendations(title, cosine_sim=cosine_sim):
    # Get the index of the movie that matches the title
    idx = indices[title]

    # Get the pairwsie similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_sim[idx]))

    # Sort the movies based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar movies
    sim_scores = sim_scores[1:11]

    # Get the movie indices
    movie_indices = [i[0] for i in sim_scores]

    # Return the top 10 most similar movies
    return data['movie_title'].iloc[movie_indices]

# %%
get_recommendations('the gentlemen', cosine_sim)
# Out:
# 3374                                     snatch
# 4782        lock, stock and two smoking barrels
# 299                              the other guys
# 421                                 tower heist
# 576                     the man from u.n.c.l.e.
# 757                 austin powers in goldmember
# 833     miss congeniality 2: armed and fabulous
# 1012                             22 jump street
# 1014                       central intelligence
# 1256                             21 jump street
# Name: movie_title, dtype: object

# %%
doc_term_matrix = count_matrix.todense()
df = pd.DataFrame(doc_term_matrix, columns=count.get_feature_names(), index=data['movie_title'])
df
# Out:
#                                           300ml  50cent  aaliyah  \
# movie_title
# avatar                                        0       0        0
# pirates of the caribbean: at world's end      0       0        0
# spectre                                       0       0        0
# the dark knight rises                         0       0        0
# john carter                                   0       0        0
# ...                                         ...     ...      ...
# top gun: maverick                             0       0        0
# the croods 2                                  0       0        0
# the last duel                                 0       0        0
# news of the world                             0       0        0
# respect                                       0       0        0
#
#                                           aaronashmore  aaronhann  aaronhill  \
# movie_title
# avatar                                               0          0          0
# pirates of the caribbean: at world's end             0          0          0
# spectre                                              0          0          0
# the dark knight rises                                0          0          0
# john carter                                          0          0          0
# ...                                                ...        ...        ...
# top gun: maverick                                    0          0          0
# the croods 2                                         0          0          0
# the last duel                                        0          0          0
# news of the world                                    0          0          0
# respect                                              0          0          0
#
#                                           aaronhughes  aaronkatz  aaronleong  \
# movie_title
# avatar                                              0          0           0
# pirates of the caribbean: at world's end            0          0           0
# spectre                                             0          0           0
# the dark knight rises                               0          0           0
# john carter                                         0          0           0
# ...                                               ...        ...         ...
# top gun: maverick                                   0          0           0
# the croods 2                                        0          0           0
# the last duel                                       0          0           0
# news of the world                                   0          0           0
# respect                                             0          0           0
#
#                                           aaronmoten  ...  élodieyung  \
# movie_title                                           ...
# avatar                                             0  ...           0
# pirates of the caribbean: at world's end           0  ...           0
# spectre                                            0  ...           0
# the dark knight rises                              0  ...           0
# john carter                                        0  ...           0
# ...                                              ...  ...         ...
# top gun: maverick                                  0  ...           0
# the croods 2                                       0  ...           0
# the last duel                                      0  ...           0
# news of the world                                  0  ...           0
# respect                                            0  ...           0
#
#                                           émilegaudreault  émiliedequenne  \
# movie_title
# avatar                                                  0               0
# pirates of the caribbean: at world's end                0               0
# spectre                                                 0               0
# the dark knight rises                                   0               0
# john carter                                             0               0
# ...                                                   ...             ...
# top gun: maverick                                       0               0
# the croods 2                                            0               0
# the last duel                                           0               0
# news of the world                                       0               0
# respect                                                 0               0
#
#                                           érictessier  étiennefaure  \
# movie_title
# avatar                                              0             0
# pirates of the caribbean: at world's end            0             0
# spectre                                             0             0
# the dark knight rises                               0             0
# john carter                                         0             0
# ...                                               ...           ...
# top gun: maverick                                   0             0
# the croods 2                                        0             0
# the last duel                                       0             0
# news of the world                                   0             0
# respect                                             0             0
#
#                                           ólafurdarriólafsson  óscarjaenada  \
# movie_title
# avatar                                                      0             0
# pirates of the caribbean: at world's end                    0             0
# spectre                                                     0             0
# the dark knight rises                                       0             0
# john carter                                                 0             0
# ...                                                       ...           ...
# top gun: maverick                                           0             0
# the croods 2                                                0             0
# the last duel                                               0             0
# news of the world                                           0             0
# respect                                                     0             0
#
#                                           ølgaard  úrsulacorberó  \
# movie_title
# avatar                                          0              0
# pirates of the caribbean: at world's end        0              0
# spectre                                         0              0
# the dark knight rises                           0              0
# john carter                                     0              0
# ...                                           ...            ...
# top gun: maverick                               0              0
# the croods 2                                    0              0
# the last duel                                   0              0
# news of the world                               0              0
# respect                                         0              0
#
#                                           михаилпореченков
# movie_title
# avatar                                                   0
# pirates of the caribbean: at world's end                 0
# spectre                                                  0
# the dark knight rises                                    0
# john carter                                              0
# ...                                                    ...
# top gun: maverick                                        0
# the croods 2                                             0
# the last duel                                            0
# news of the world                                        0
# respect                                                  0
#
# [6984 rows x 11141 columns]

# %%
df2 = pd.DataFrame(cosine_sim, columns=data['movie_title'], index=data['movie_title'])
df2
# Out:
# movie_title                                 avatar  \
# movie_title
# avatar                                    1.000000
# pirates of the caribbean: at world's end  0.377964
# spectre                                   0.251976
# the dark knight rises                     0.125988
# john carter                               0.471405
# ...                                            ...
# top gun: maverick                         0.136083
# the croods 2                              0.125988
# the last duel                             0.000000
# news of the world                         0.000000
# respect                                   0.000000
#
# movie_title                               pirates of the caribbean: at world's end  \
# movie_title
# avatar                                                                    0.377964
# pirates of the caribbean: at world's end                                  1.000000
# spectre                                                                   0.285714
# the dark knight rises                                                     0.142857
# john carter                                                               0.267261
# ...                                                                            ...
# top gun: maverick                                                         0.154303
# the croods 2                                                              0.142857
# the last duel                                                             0.000000
# news of the world                                                         0.000000
# respect                                                                   0.000000
#
# movie_title                                spectre  the dark knight rises  \
# movie_title
# avatar                                    0.251976               0.125988
# pirates of the caribbean: at world's end  0.285714               0.142857
# spectre                                   1.000000               0.285714
# the dark knight rises                     0.285714               1.000000
# john carter                               0.267261               0.133631
# ...                                            ...                    ...
# top gun: maverick                         0.154303               0.154303
# the croods 2                              0.142857               0.000000
# the last duel                             0.000000               0.000000
# news of the world                         0.000000               0.000000
# respect                                   0.000000               0.000000
#
# movie_title                               john carter   tangled   tangled  \
# movie_title
# avatar                                       0.471405  0.201008  0.201008
# pirates of the caribbean: at world's end     0.267261  0.227921  0.227921
# spectre                                      0.267261  0.113961  0.113961
# the dark knight rises                        0.133631  0.000000  0.000000
# john carter                                  1.000000  0.106600  0.106600
# ...                                               ...       ...       ...
# top gun: maverick                            0.144338  0.000000  0.000000
# the croods 2                                 0.133631  0.341882  0.341882
# the last duel                                0.000000  0.000000  0.000000
# news of the world                            0.000000  0.000000  0.000000
# respect                                      0.000000  0.000000  0.000000
#
# movie_title                               avengers: age of ultron  \
# movie_title
# avatar                                                   0.471405
# pirates of the caribbean: at world's end                 0.267261
# spectre                                                  0.267261
# the dark knight rises                                    0.133631
# john carter                                              0.500000
# ...                                                           ...
# top gun: maverick                                        0.144338
# the croods 2                                             0.133631
# the last duel                                            0.000000
# news of the world                                        0.000000
# respect                                                  0.000000
#
# movie_title                               harry potter and the half-blood prince  \
# movie_title
# avatar                                                                  0.235702
# pirates of the caribbean: at world's end                                0.267261
# spectre                                                                 0.133631
# the dark knight rises                                                   0.000000
# john carter                                                             0.125000
# ...                                                                          ...
# top gun: maverick                                                       0.000000
# the croods 2                                                            0.267261
# the last duel                                                           0.000000
# news of the world                                                       0.000000
# respect                                                                 0.000000
#
# movie_title                               batman v superman: dawn of justice  \
# movie_title
# avatar                                                              0.444444
# pirates of the caribbean: at world's end                            0.251976
# spectre                                                             0.251976
# the dark knight rises                                               0.125988
# john carter                                                         0.471405
# ...                                                                      ...
# top gun: maverick                                                   0.136083
# the croods 2                                                        0.125988
# the last duel                                                       0.000000
# news of the world                                                   0.000000
# respect                                                             0.000000
#
# movie_title                               ...      soul  happiest season  \
# movie_title                               ...
# avatar                                    ...  0.000000              0.0
# pirates of the caribbean: at world's end  ...  0.000000              0.0
# spectre                                   ...  0.142857              0.0
# the dark knight rises                     ...  0.142857              0.0
# john carter                               ...  0.000000              0.0
# ...                                       ...       ...              ...
# top gun: maverick                         ...  0.000000              0.0
# the croods 2                              ...  0.000000              0.0
# the last duel                             ...  0.000000              0.0
# news of the world                         ...  0.000000              0.0
# respect                                   ...  0.000000              0.0
#
# movie_title                               voyagers  free guy  \
# movie_title
# avatar                                    0.000000  0.316228
# pirates of the caribbean: at world's end  0.000000  0.358569
# spectre                                   0.133631  0.239046
# the dark knight rises                     0.133631  0.119523
# john carter                               0.000000  0.223607
# ...                                            ...       ...
# top gun: maverick                         0.000000  0.129099
# the croods 2                              0.000000  0.239046
# the last duel                             0.000000  0.141421
# news of the world                         0.000000  0.000000
# respect                                   0.000000  0.000000
#
# movie_title                               coming 2 america  top gun: maverick  \
# movie_title
# avatar                                                 0.0           0.136083
# pirates of the caribbean: at world's end               0.0           0.154303
# spectre                                                0.0           0.154303
# the dark knight rises                                  0.0           0.154303
# john carter                                            0.0           0.144338
# ...                                                    ...                ...
# top gun: maverick                                      0.0           1.000000
# the croods 2                                           0.0           0.000000
# the last duel                                          0.0           0.182574
# news of the world                                      0.0           0.166667
# respect                                                0.0           0.166667
#
# movie_title                               the croods 2  the last duel  \
# movie_title
# avatar                                        0.125988       0.000000
# pirates of the caribbean: at world's end      0.142857       0.000000
# spectre                                       0.142857       0.000000
# the dark knight rises                         0.000000       0.000000
# john carter                                   0.133631       0.000000
# ...                                                ...            ...
# top gun: maverick                             0.000000       0.182574
# the croods 2                                  1.000000       0.000000
# the last duel                                 0.000000       1.000000
# news of the world                             0.000000       0.182574
# respect                                       0.000000       0.182574
#
# movie_title                               news of the world   respect
# movie_title
# avatar                                             0.000000  0.000000
# pirates of the caribbean: at world's end           0.000000  0.000000
# spectre                                            0.000000  0.000000
# the dark knight rises                              0.000000  0.000000
# john carter                                        0.000000  0.000000
# ...                                                     ...       ...
# top gun: maverick                                  0.166667  0.166667
# the croods 2                                       0.000000  0.000000
# the last duel                                      0.182574  0.182574
# news of the world                                  1.000000  0.166667
# respect                                            0.166667  1.000000
#
# [6984 rows x 6984 columns]

# %%
rec = get_recommendations('the gentlemen', cosine_sim)

# %%
rec.tolist()
# Out:
# ['snatch',
#  'lock, stock and two smoking barrels',
#  'the other guys',
#  'tower heist',
#  'the man from u.n.c.l.e.',
#  'austin powers in goldmember',
#  'miss congeniality 2: armed and fabulous',
#  '22 jump street',
#  'central intelligence',
#  '21 jump street']
